# %% [markdown]
# # Matplotlib

# %% [markdown]
# ## 라인 플롯

# %%
# !apt-get install -y fonts-nanum > /dev/null
# !fc-cache -fv > /dev/null
# !rm ~/.cache/matplotlib -rf > /dev/null

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='NanumBarunGothic')

# %% [markdown]
# * 반드시 런타임 다시시작 !!

# %%
plt.title("라인 플롯")
plt.plot([1, 4, 9, 16])  # y = (x + 1) ** 2 제곱
plt.grid()
plt.show()
# %matplotlib inline 과거 주피터노트북에서 그래프를 볼 때 매직명령을 써줘야 했는데 지금은 안 써도 된다

# %%
plt.title("라인 플롯")
xs = np.linspace(0, 3, 301)
ys = (xs + 1) ** 2
plt.plot(xs, ys)  # y = (x + 1) ** 2 제곱
plt.grid()
plt.show()

# %% [markdown]
# ## 스타일 지정
# * 색(Red, Blue, Cyan, Magenta, blacK, Green, Yellow, White
# * 마커는 위치(. ,
# * 선스타일 (solid - , -- dashed, -. dash-dot, : dotted )

# %%
plt.title("'rs--' 스타일의 plot ")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], 'rs:')  #앞이 x데이터 뒤가 y데이터, rs-- 는 색을 지정
plt.grid()
plt.show()

# %%
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], c="b",
         lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")  # lw 선 굵기
plt.title("스타일 적용 예")
plt.grid()
plt.show()

# %% [markdown]
# ## 그림 범위 지정
#
# * xlim 명령 ylim 명령. 이 명령들은 그림의 범위가 되는 x축, y축의 최소값과 최대값을 지정

# %%
plt.title("x축, y축의 범위 설정")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16],
         c="b", lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
plt.xlim(0, 50)
plt.ylim(-10, 30)
plt.grid()
plt.show()

# %% [markdown]
# ## 틱 설정
#
# * 플롯이나 차트에서 축상의 위치 표시 지점을 틱(tick)이라고 하고 이 틱에 써진 숫자 혹은 글자를 틱 라벨(tick label)이라고 한다. 틱의 위치나 틱 라벨은 맷플롯리브가 자동으로 정해주지만 만약 수동으로 설정하고 싶다면 xticks 명령이나 yticks 명령을 사용한다.

# %%
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.title("x축과 y축의 tick label 설정")
plt.plot(X, C)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
plt.yticks([-1, 0, +1])
plt.grid()
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.title("LaTeX, 문자열로 tick label 정의")
plt.plot(X, C)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi],
           [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, 1], ["Low", "Zero", "High"])
plt.grid()
plt.show()

# %%
t = np.arange(0., 5., 0.2)
plt.title("라인 플롯에서 여러개의 선 그리기")
plt.plot(t, t, 'r--', t, 0.5 * t**2, 'bs:', t, 0.2 * t**3, 'g^-')
plt.gird()
plt.show()

# %%
plt.title("라인 플롯에서 여러개의 선 그리기")
plt.plot(t, t, 'r--')
plt.plot(t, 0.5 * t**2, 'bs:')
plt.plot(t, 0.2 * t**3, 'g^-')
plt.grid()
plt.show()

# %% [markdown]
# ## 범례(legend)

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.title("legend를 표시한 플롯")
plt.plot(X, C, label="cosine")
plt.plot(X, S, label="sine")
plt.legend()   
plt.grid()
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.title("legend를 표시한 플롯")
plt.plot(X, C, label="cosine")
plt.plot(X, S, label="sine")
plt.legend(loc='lower center')  
plt.grid()
plt.show()

# %% [markdown]
# ## x축, y축 라벨, 타이틀

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.plot(X, C, label="cosine")
plt.xlabel("time")
plt.ylabel("amplitude")
plt.title("Cosine Plot")
plt.grid()
plt.show()
